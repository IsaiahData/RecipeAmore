# %%
Recipes Allmore
# Out:
#   File "<ipython-input-6-b7d8348e3539>", line 1
#     Recipes Allmore
#                   ^
# SyntaxError: invalid syntax

# %%
from recipe_scrapers import scrape_me
import pandas as pd
import numpy as np
import time

# %%
# # To test the scraper, a single scrape is performed. There may be recipes with lower numbers, but this is the lowest yet found.
# scraper = scrape_me('https://www.allrecipes.com/recipe/6663/')

# # Different methods become available with the scraper modules. To test them, uncomment and run the code on scraper.
# # scraper.title()
# # scraper.total_time()
# # scraper.ingredients()
# # scraper.instructions()
# # scraper.links()

# To run a scrape across allrecipes.com, a function is needed. 
scrape_url_nude = 'https://www.allrecipes.com/recipe/' # a baseline URL for the function
recipe_numbers  = list(range(4401, 6663))
# recipe_numbers  = list(range(21751, 300000)) # Recipe numbers.Thusfar, only recipes between 6663 and 18660, inclusive, have been collected. 300000 is an arbitrary endpoint.
len(recipe_numbers) # Checking how many recipes we are attempting to scrape. This is a test, not a function component.
recipe_df_columns = ['Recipe Number', 'Title', 'Total Time', 'Ingredients', 'Instructions'] # Intended columns for the scrape's output dataframe. 
recipe_df = pd.DataFrame(columns = recipe_df_columns) # Instantiating the dataframe. 

def the_big_scrape(): # a function that starts the scrape. 
    for rec in recipe_numbers:
        try: 
            scraped = scrape_me(scrape_url_nude+str(rec))
            recipe_df.loc[rec]= [rec, scraped.title(), scraped.total_time(), scraped.ingredients(), scraped.instructions()]
# # The following two lines were intended to skip 404ed pages, but resulted in no scraping taking plac.e. Unsure why. Can clean on the back end. 
#             if scrape.title() == 'Bummer.': # 'Bummer.' is the title of URLs which have no recipe, their 404 message. 
#                 continue
            if rec % 10 == 0: # saving every time a recipe with a factor of 10 isn't 404. If something goes wrong with the scrape, previous materials are saved. 
                recipe_df.to_csv('./recipe_df3.csv')
        except:
            continue
        time.sleep(1) # scrapes once every three seconds. 

the_big_scrape() # runs the scrape

# %%
recipe_df2 = pd.read_csv('./recipe_df.csv')
recipe_df2['Ingredients'].head(3)
# Out:
# 0    ['1/2 cup Parmesan cheese', '3/4 teaspoon grou...
# 1    ['1/2 cup unsalted butter, chilled and cubed',...
# 2    ['2 cups hot water', '1/2 cup margarine', '1/3...
# Name: Ingredients, dtype: object

# %%
recipe_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10366 entries, 0 to 10365
# Data columns (total 6 columns):
# Unnamed: 0       10366 non-null int64
# Recipe Number    10366 non-null int64
# Title            10366 non-null object
# Total Time       10366 non-null int64
# Ingredients      10366 non-null object
# Instructions     10255 non-null object
# dtypes: int64(3), object(3)
# memory usage: 486.0+ KB

# %%
recipe_df2.head(3)
# Out:
#    Unnamed: 0  Recipe Number  \
# 0        6663           6663
# 1        6664           6664
# 2        6665           6665
#
#                                                Title  Total Time  \
# 0                               Crispy Cheese Twists           0
# 1  Basil, Roasted Peppers and Monterey Jack Cornb...         100
# 2                                  Mom's Yeast Rolls           0
#
#                                          Ingredients  \
# 0  ['1/2 cup Parmesan cheese', '3/4 teaspoon grou...
# 1  ['1/2 cup unsalted butter, chilled and cubed',...
# 2  ['2 cups hot water', '1/2 cup margarine', '1/3...
#
#                                         Instructions
# 0  Combine parmesan cheese, pepper and garlic pow...
# 1  Preheat oven to 400 degrees F (205 degrees C)....
# 2  Melt margarine in hot water. Add sugar and sal...

# %% [markdown]
# ## Defining a recipe
#
# ---
# Each recipe needs a set of characteristics, stored in variables. These variables will be stored in dictionaries.
#
# The recipe variables are:
#
#     Recipe ID: The unique number that appends the recipe url on allrecipes.com (integer)
#     Title: The name of the recipe (string)
#     Total time: The number of minutes the recipe should take to prepare and cook. (integer)
#     Ingredients: The ingredients that go into the recipe. (list of strings)
#     Instructions: Step-by-step cooking instructions (list)
#
# Sometimes these variables are unideal. Many cooking times are missing. Recipes are also user-submitted and this product currently does not take into account ratings. This could lead to some odd inputs.

# %% [markdown]
# ## Bummer.
# ---
# Many of the entries are empty. If the Title is 'Bummer.', it will need to be cleared out.

# %%
recipe_df2.loc[recipe_df2['Title'] == 'Bummer.'].count()
# Out:
# Unnamed: 0       111
# Recipe Number    111
# Title            111
# Total Time       111
# Ingredients      111
# Instructions       0
# dtype: int64

# %%
recipe_df2
# Out:
#        Unnamed: 0  Recipe Number  \
# 0            6663           6663
# 1            6664           6664
# 2            6665           6665
# 3            6666           6666
# 4            6667           6667
# 5            6668           6668
# 6            6669           6669
# 7            6670           6670
# 8            6671           6671
# 9            6672           6672
# 10           6673           6673
# 11           6674           6674
# 12           6675           6675
# 13           6676           6676
# 14           6677           6677
# 15           6678           6678
# 16           6679           6679
# 17           6680           6680
# 18           6681           6681
# 19           6682           6682
# 20           6683           6683
# 21           6684           6684
# 22           6685           6685
# 23           6686           6686
# 24           6687           6687
# 25           6688           6688
# 26           6689           6689
# 27           6690           6690
# 28           6691           6691
# 29           6692           6692
# ...           ...            ...
# 10336       18617          18617
# 10337       18618          18618
# 10338       18619          18619
# 10339       18621          18621
# 10340       18622          18622
# 10341       18624          18624
# 10342       18625          18625
# 10343       18627          18627
# 10344       18628          18628
# 10345       18629          18629
# 10346       18630          18630
# 10347       18632          18632
# 10348       18633          18633
# 10349       18635          18635
# 10350       18636          18636
# 10351       18638          18638
# 10352       18639          18639
# 10353       18640          18640
# 10354       18642          18642
# 10355       18643          18643
# 10356       18644          18644
# 10357       18645          18645
# 10358       18647          18647
# 10359       18648          18648
# 10360       18650          18650
# 10361       18654          18654
# 10362       18655          18655
# 10363       18657          18657
# 10364       18658          18658
# 10365       18660          18660
#
#                                                    Title  Total Time  \
# 0                                   Crispy Cheese Twists           0
# 1      Basil, Roasted Peppers and Monterey Jack Cornb...         100
# 2                                      Mom's Yeast Rolls           0
# 3                                   Sweet Potato Bread I           0
# 4                                         Cornish Splits           0
# 5                                            Orange Buns         170
# 6                                  Jalapeno Cheese Bread           0
# 7                                     Dee's Health Bread           0
# 8                                        Oatmeal Bread I           0
# 9                                     Strawberry Bread I           0
# 10              Sun Dried Tomato and Asiago Cheese Bread           0
# 11                                  Hawaiian Sweet Bread           0
# 12                   The Best Corn Bread You'll Ever Eat          35
# 13                           No Knead Refrigerator Rolls           0
# 14                                   Sourdough Starter I           0
# 15                                     Sourdough Bread I           0
# 16                                           Dilly Bread         145
# 17                                       Pumpkin Bread I          75
# 18                                          Sy's Challah           0
# 19                                         Onion Bread I           0
# 20                        Grandma VanDoren's White Bread           0
# 21                                       Italian Bread I           0
# 22                                   Sunday Dinner Rolls           0
# 23                                    Banana Wheat Bread           0
# 24                                          Banana Bread          75
# 25                                   Candied Fruit Bread           0
# 26                                   Nut and Fruit Bread           0
# 27                                 Mother's Banana Bread          75
# 28                                  Pumpernickel Bread I           0
# 29                             Sun Dried Tomato Focaccia           0
# ...                                                  ...         ...
# 10336                                            Bummer.           0
# 10337                                            Bummer.           0
# 10338                                            Bummer.           0
# 10339                                            Bummer.           0
# 10340                                            Bummer.           0
# 10341                                            Bummer.           0
# 10342                                            Bummer.           0
# 10343                                            Bummer.           0
# 10344                                            Bummer.           0
# 10345                                            Bummer.           0
# 10346                                            Bummer.           0
# 10347                                            Bummer.           0
# 10348                                            Bummer.           0
# 10349                                            Bummer.           0
# 10350                                            Bummer.           0
# 10351                                            Bummer.           0
# 10352                                            Bummer.           0
# 10353                                            Bummer.           0
# 10354                                            Bummer.           0
# 10355                                            Bummer.           0
# 10356                                            Bummer.           0
# 10357                                            Bummer.           0
# 10358                                            Bummer.           0
# 10359                                            Bummer.           0
# 10360                                            Bummer.           0
# 10361                                            Bummer.           0
# 10362                                            Bummer.           0
# 10363                                            Bummer.           0
# 10364                                            Bummer.           0
# 10365                                            Bummer.           0
#
#                                              Ingredients  \
# 0      ['1/2 cup Parmesan cheese', '3/4 teaspoon grou...
# 1      ['1/2 cup unsalted butter, chilled and cubed',...
# 2      ['2 cups hot water', '1/2 cup margarine', '1/3...
# 3      ['1 1/2 cups white sugar', '1/2 cup vegetable ...
# 4      ['1 teaspoon active dry yeast', '1 1/4 cups lu...
# 5      ['1/4 cup butter', '1 teaspoon white sugar', '...
# 6      ['8 cups all-purpose flour', '4 cups shredded ...
# 7      ['2 tablespoons active dry yeast', '1 teaspoon...
# 8      ['1 cup rolled oats', '1/2 cup molasses', '1/3...
# 9      ['3 cups all-purpose flour', '2 cups white sug...
# 10     ['1 cup water', '2 tablespoons extra virgin ol...
# 11     ['1 cup warm water', '5 tablespoons white suga...
# 12     ['1 egg', '1 1/3 cups milk', '1/4 cup vegetabl...
# 13     ['4 1/2 teaspoons active dry yeast', '2 cups w...
# 14     ['3 tablespoons instant mashed potato flakes',...
# 15     ['1 cup sourdough starter', '1 1/2 cups warm w...
# 16     ['1 (.25 ounce) package active dry yeast', '1/...
# 17     ['3 1/2 cups all-purpose flour', '2 teaspoons ...
# 18     ['1/4 cup white sugar', '1 tablespoon salt', '...
# 19     ['2 (.25 ounce) packages active dry yeast', '3...
# 20     ['3 cups warm water', '3 tablespoons active dr...
# 21     ['1/4 cup chopped sun-dried tomatoes', '2 1/2 ...
# 22     ['1 (.25 ounce) package active dry yeast', '1/...
# 23     ['2 cups whole wheat flour', '1/4 cup wheat ge...
# 24     ['1 1/2 cups all-purpose flour', '1 teaspoon b...
# 25     ['2 cups sifted all-purpose flour', '4 teaspoo...
# 26     ['2 cups sifted all-purpose flour', '4 teaspoo...
# 27     ['1 3/4 cups all-purpose flour', '2 teaspoons ...
# 28     ['1 1/2 cups warm milk', '1 1/2 tablespoons ve...
# 29     ['1 cup water', '3 cups bread flour', '2 table...
# ...                                                  ...
# 10336                                                 []
# 10337                                                 []
# 10338                                                 []
# 10339                                                 []
# 10340                                                 []
# 10341                                                 []
# 10342                                                 []
# 10343                                                 []
# 10344                                                 []
# 10345                                                 []
# 10346                                                 []
# 10347                                                 []
# 10348                                                 []
# 10349                                                 []
# 10350                                                 []
# 10351                                                 []
# 10352                                                 []
# 10353                                                 []
# 10354                                                 []
# 10355                                                 []
# 10356                                                 []
# 10357                                                 []
# 10358                                                 []
# 10359                                                 []
# 10360                                                 []
# 10361                                                 []
# 10362                                                 []
# 10363                                                 []
# 10364                                                 []
# 10365                                                 []
#
#                                             Instructions
# 0      Combine parmesan cheese, pepper and garlic pow...
# 1      Preheat oven to 400 degrees F (205 degrees C)....
# 2      Melt margarine in hot water. Add sugar and sal...
# 3      Combine sugar and oil; beat well. Add eggs and...
# 4      In a small bowl, dissolve the yeast in the mil...
# 5      Stir butter and 1 teaspoon sugar into the hot ...
# 6      In a very large bowl, combine 7 cups of flour,...
# 7      In a small bowl, dissolve the yeast and sugar ...
# 8      Combine oats, molasses, oil, salt and boiling ...
# 9      Grease and flour a 9 x 5 inch pan well. Prehea...
# 10     Place all ingredients into bread machine in or...
# 11     Measure ingredients into the bread machine in ...
# 12     Heat oven to 425 degrees F (220 degrees C). Gr...
# 13     In a large bowl, dissolve yeast in warm water ...
# 14     Combine instant potatoes, sugar, water, and ye...
# 15     Mix sugar, corn oil, salt, water, and 1 cup of...
# 16     Stir the yeast into the warm water, and add a ...
# 17     Preheat oven to 350 degrees F (175 degrees C)....
# 18     Place sugar, salt, and oil in either a mixing ...
# 19     Warm the milk in a small saucepan until it bub...
# 20     In a large bowl, combine warm water, yeast, sa...
# 21     Preheat oven to 350 degrees F (175 degrees C)....
# 22     In a large bowl, stir yeast, 1/4 cup warm wate...
# 23     Grease a 9 x 5 inch loaf pan. Preheat oven to ...
# 24     Grease and flour two 7x3 inch loaf pans. Prehe...
# 25     Grease an 8 x 5 inch loaf tin thoroughly. Preh...
# 26     Grease an 8 x 5 inch loaf tin thoroughly. Preh...
# 27     Grease an 8x4 inch loaf pan. Preheat oven to 3...
# 28     Place ingredients into the bread machine in or...
# 29     Place water, flour, powdered milk, sugar, salt...
# ...                                                  ...
# 10336                                                NaN
# 10337                                                NaN
# 10338                                                NaN
# 10339                                                NaN
# 10340                                                NaN
# 10341                                                NaN
# 10342                                                NaN
# 10343                                                NaN
# 10344                                                NaN
# 10345                                                NaN
# 10346                                                NaN
# 10347                                                NaN
# 10348                                                NaN
# 10349                                                NaN
# 10350                                                NaN
# 10351                                                NaN
# 10352                                                NaN
# 10353                                                NaN
# 10354                                                NaN
# 10355                                                NaN
# 10356                                                NaN
# 10357                                                NaN
# 10358                                                NaN
# 10359                                                NaN
# 10360                                                NaN
# 10361                                                NaN
# 10362                                                NaN
# 10363                                                NaN
# 10364                                                NaN
# 10365                                                NaN
#
# [10366 rows x 6 columns]
