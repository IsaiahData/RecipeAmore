# %% [markdown]
# # Recipes Amore
# ---
# What are you in the mood to cook today?
# Maybe you have a specific craving or even just an ingredient lying around you're trying to use.
#
# Thousands of recipes have been collected from allrecipes.com and have been compiled to help. Using this recipe recommender system, all you need to do is enter those ingredients you're in the mood for and then choose something delicious to make from the results!

# %%
# !pip install --upgrade git+git://github.com/hhursev/recipe-scrapers.git
# Consider adding calories and serving sizes

# %%
from recipe_scrapers import scrape_me
import pandas as pd
import numpy as np
import time

# %%
# To test the scraper, a single scrape is performed. There may be recipes with lower numbers, but this is the lowest yet found.
# scraper = scrape_me('https://www.allrecipes.com/recipe/6663/')

# # Different methods become available with the scraper modules. To test them, uncomment and run the code on scraper.
# # scraper.title()
# # scraper.total_time()
# # scraper.ingredients()
# # scraper.instructions()
# # scraper.links()

# %%
# ### DON'T MESS WITH THIS. IT DOES THE THING.


# # To run a scrape across allrecipes.com, a function is needed. 
# scrape_url_nude = 'https://www.allrecipes.com/recipe/' # a baseline URL for the function
# recipe_numbers  = list(range(18661, 300000)) # Recipe numbers.Thusfar, only recipes between 6663 and 18660, inclusive, have been collected. 300000 is an arbitrary endpoint.
# len(recipe_numbers) # Checking how many recipes we are attempting to scrape. This is a test, not a function component.
# recipe_df_columns = ['Recipe Number', 'Title', 'Total Time', 'Ingredients', 'Instructions'] # Intended columns for the scrape's output dataframe. 
# recipe_df = pd.DataFrame(columns = recipe_df_columns) # Instantiating the dataframe. 

# def the_big_scrape(): # a function that starts the scrape. 
#     for rec in recipe_numbers:
#         try: 
#             scraped = scrape_me(scrape_url_nude+str(rec))
#             recipe_df.loc[rec]= [rec, scraped.title(), scraped.total_time(), scraped.ingredients(), scraped.instructions()]
# # # The following two lines were intended to skip 404ed pages, but resulted in no scraping taking plac.e. Unsure why. Can clean on the back end. 
# #             if scrape.title() == 'Bummer.': # 'Bummer.' is the title of URLs which have no recipe, their 404 message. 
# #                 continue
#             if rec % 10 == 0: # saving every time a recipe with a factor of 10 isn't 404. If something goes wrong with the scrape, previous materials are saved. 
#                 recipe_df.to_csv('./recipe_df3.csv')
#         except:
#             continue
#         time.sleep(1) # scrapes once every three seconds. 

# the_big_scrape() # runs the scrape

# %%
# ### DON'T MESS WITH THIS. IT DOES THE THING.


# # To run a scrape across allrecipes.com, a function is needed. 
# scrape_url_nude = 'https://www.allrecipes.com/recipe/' # a baseline URL for the function
# recipe_numbers  = list(range(12280, 48200)) # Recipe numbers. 48200 is the last number I need/want until after Nov 2018.
# len(recipe_numbers) # Checking how many recipes we are attempting to scrape. This is a test, not a function component.
# recipe_df_columns = ['Recipe Number', 'Rating', 'Number of Ratings'] # Intended columns for the scrape's output dataframe. 
# recipe_df = pd.DataFrame(columns = recipe_df_columns) # Instantiating the dataframe. 

# def the_big_scrape(recipe_numbers): # a function that starts the scrape. 
#     for rec in recipe_numbers:
#         try: 
#             req = requests.get(scrape_url_nude+str(rec))
#             soup = BeautifulSoup(req.text, 'lxml')
#             rating = soup.find_all('div', {'class': 'rating-stars'})[0]['data-ratingstars']  # Rating: <div class="rating-stars" onclick="AnchorScroll('reviews')" data-ratingstars="4.17647075653076">
#             num_rating = soup.find_all('h4', {'class': 'helpful-header'})[0].get_text()[:-8] # Number of Ratings: <h4 class="helpful-header">68 Ratings</h4>
#             recipe_df.loc[rec]= [rec, rating, num_rating] 
#         except:
#             rating = 0
#             num_rating = 0
#             recipe_df.loc[rec]= [rec, rating, num_rating]            
#             if rec % 10 == 0: # saving every time a recipe with a factor of 10 isn't 404. If something goes wrong with the scrape, previous materials are saved. 
#                 recipe_df.to_csv('./recipe_ratings_df.csv')
#             continue
#           time.sleep(1) # scrapes once every second. 
# the_big_scrape(recipe_numbers) # runs the scrape

# %%
recipe_df_raw = pd.read_csv('./recipes 48200 ratings 210 new.csv')
recipe_df_raw.head(4)
# Out:
#    Unnamed: 0  Recipe Number                                     Title  \
# 0           0              0                                   Bummer.
# 1           1              1                                   Bummer.
# 2           2              2                                   Bummer.
# 3           3              3  Mexican Strawberry Water (Agua de Fresa)
#
#    Total Time                                        Ingredients Instructions  \
# 0           0                                                 []          NaN
# 1           0                                                 []          NaN
# 2           0                                                 []          NaN
# 3         265  ['4 cups strawberries, sliced', '1 cup white s...          NaN
#
#    Rating  Number of Ratings
# 0    0.00                0.0
# 1    0.00                0.0
# 2    0.00                0.0
# 3    4.65               80.0

# %% [markdown]
# ### Defining a recipe
#
# ---
# Each recipe needs a set of characteristics, variables, stored within columns of a Pandas DataFrame.
#
# The recipe variables are:
#
#     Recipe ID: The unique number that appends the recipe url on allrecipes.com (integer)
#     Title: The name of the recipe (string)
#     Total time: The number of minutes the recipe should take to prepare and cook. (integer)
#     Ingredients: The ingredients that go into the recipe. (list of strings)
#     Instructions: Step-by-step cooking instructions (list)
#     Rating: The average rating left by users
#     Number of ratings: The number of ratings left by users.
#
# Sometimes these variables are unideal. Many cooking times are missing. Recipes are user-submitted and this product, Recipe Amore, currently does not take into account ratings.

# %% [markdown]
# <img src="https://imgur.com/cfQTzEB.png" style="float: left; margin: 15px; height: 50px">
# #### 'Bummer.'
#
# Not every URL has a recipe attached. Many have been removed either by the user or by allrecipes themselves for any number of potential reasons. Allrecipes.com uses this eggy image for their 404 to let you know they don't have a recipe there. Before building the recommender system, it was important to ahve these cleared out so you can better guarantee every recipe you see will be a winner!

# %%
# Look at the data
recipe_df_raw.head(4)
# Out:
#    Unnamed: 0  Recipe Number                                     Title  \
# 0           0              0                                   Bummer.
# 1           1              1                                   Bummer.
# 2           2              2                                   Bummer.
# 3           3              3  Mexican Strawberry Water (Agua de Fresa)
#
#    Total Time                                        Ingredients Instructions  \
# 0           0                                                 []          NaN
# 1           0                                                 []          NaN
# 2           0                                                 []          NaN
# 3         265  ['4 cups strawberries, sliced', '1 cup white s...          NaN
#
#    Rating  Number of Ratings
# 0    0.00                0.0
# 1    0.00                0.0
# 2    0.00                0.0
# 3    4.65               80.0

# %%
# Check the size of the DataFrame
recipe_df_raw.shape # (25994, 8)
# Out:
# (25994, 8)

# %%
# showed an unexpected column, 'Unnamed: 0'
# Column 'Unnamed: 0' seems to be a copy of the recipe number. Confirm or deny this. 
(recipe_df_raw['Unnamed: 0'] == recipe_df_raw['Recipe Number']).value_counts() # demonstrates them to be exact copies. 'Unnamed: 0' will need to be removed.
# Out:
# True    25994
# dtype: int64

# %%
# Check the number of 404 URLs
recipe_df_raw.isnull().sum()
# Out:
# Unnamed: 0               0
# Recipe Number            0
# Title                    0
# Total Time               0
# Ingredients              0
# Instructions          8572
# Rating               25783
# Number of Ratings    25783
# dtype: int64

# %%
# # In case anything needs changing, it's important to know about the data
recipe_df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25994 entries, 0 to 25993
# Data columns (total 8 columns):
# Unnamed: 0           25994 non-null int64
# Recipe Number        25994 non-null int64
# Title                25994 non-null object
# Total Time           25994 non-null int64
# Ingredients          25994 non-null object
# Instructions         17422 non-null object
# Rating               211 non-null float64
# Number of Ratings    211 non-null float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 1.6+ MB

# %%
# Where 'Bummer.' appears as a title, scraper.title(), the recipe is absent. We have 8570 of these.
recipe_df_raw.loc[recipe_df_raw['Title'] == 'Bummer.'].count()
# Out:
# Unnamed: 0           8570
# Recipe Number        8570
# Title                8570
# Total Time           8570
# Ingredients          8570
# Instructions            0
# Rating                210
# Number of Ratings     210
# dtype: int64

# %%
# There are 8572 recipes without instructions. These may be blank recipes of the "Bummer." variety.
recipe_df_raw.isnull().sum() 
# Where these additional two null recipes come from is unclear, but it is safer to go by "Bummer." as it is the official allrecipes 404, rather than inferred.
# Out:
# Unnamed: 0               0
# Recipe Number            0
# Title                    0
# Total Time               0
# Ingredients              0
# Instructions          8572
# Rating               25783
# Number of Ratings    25783
# dtype: int64

# %%
# Recipes with the title "Johnsonville® Three Cheese Italian Style Chicken Sausage Skillet Pizza" appear 2202 times.
 # The next most repeated recipe titles are not identicals
recipe_df_raw['Title'].value_counts().head()
# Out:
# Bummer.                                                                   8570
# Johnsonville® Three Cheese Italian Style Chicken Sausage Skillet Pizza    2202
# English Trifle                                                               4
# Corn Pudding II                                                              3
# Delmonico Potatoes                                                           3
# Name: Title, dtype: int64

# %%
recipe_df_cooking = recipe_df_raw[recipe_df_raw['Title'] != 'Bummer.']
recipe_df_cooked = recipe_df_cooking[recipe_df_cooking['Title'] != 'Johnsonville® Three Cheese Italian Style Chicken Sausage Skillet Pizza']

# # The troubling entries are gone. If more recipes are added, more exploration will be required to confirm nothing more need be done. 
# recipe_df_cooked['Title'].value_counts()

# %% [markdown]
# ## Scraping again, a new DataFrame
# Scraping was re-performed, scraping only those rows which lacked mentions of "Bummer." or "Johnsonville® Three Cheese Italian Style Chicken Sausage Skillet Pizza". Only Rating and Number of ratings were collected. The data was added in microsoft excel and saved as CSV.
#
# More EDA is necessary.

# %%
recipe_df = pd.read_csv('./recipe_df_cooked.csv')
recipe_df.head(4)
# Out:
#    Unnamed: 0  Recipe Number  \
# 0           3              3
# 1        6663           6663
# 2        6664           6664
# 3        6665           6665
#
#                                                Title  Total Time  \
# 0           Mexican Strawberry Water (Agua de Fresa)         265
# 1                               Crispy Cheese Twists           0
# 2  Basil, Roasted Peppers and Monterey Jack Cornb...         100
# 3                                  Mom's Yeast Rolls           0
#
#                                          Ingredients  \
# 0  ['4 cups strawberries, sliced', '1 cup white s...
# 1  ['1/2 cup Parmesan cheese', '3/4 teaspoon grou...
# 2  ['1/2 cup unsalted butter, chilled and cubed',...
# 3  ['2 cups hot water', '1/2 cup margarine', '1/3...
#
#                                         Instructions    Rating  \
# 0                                                NaN  4.650000
# 1  Combine parmesan cheese, pepper and garlic pow...  4.176471
# 2  Preheat oven to 400 degrees F (205 degrees C)....  4.327586
# 3  Melt margarine in hot water. Add sugar and sal...  3.623116
#
#    Number of Ratings
# 0               80.0
# 1               68.0
# 2               58.0
# 3              199.0

# %%
recipe_df.shape
# Out:
# (15222, 8)

# %%
# # Checking the most common number of ratings.
# # Excel showed many empty ratings.
# # If the number is excessive, these recipes will be removed to clean the dataset.
# # This is often due to erroneous scraping, not an actual lack of recipes.
# # This was verified by checking some recipes values in the DataFrame vs checking their URL.
# # The cause is currently undetermined. 
# # There are 5086 recipes with no rating information.
# # A recommender system is to be build on these ratings.
# # They will be removed for the prototype.
# recipe_df['Number of Ratings'].value_counts()

# %%
# A new DataFrame is designed for the recommender system without the zero-value-'Number of Ratings' entries
rr_df = recipe_df[recipe_df['Number of Ratings'] != 0]
# rr_df['Number of Ratings'].value_counts() # Success.

# %% [markdown]
# While the recommender system is a cookbook, it makes sense to list our article in the rows of our DataFrame.
# Each row is a recipe.
# The recommender system's article of interest is the customer utilizing the recipe.
# In the recommender system, we will put users in rows.

# %% [markdown]
# # Head down to the "Recommender System" section below!

# %% [markdown]
# ### Example recipe
# Recipes will again contain the following:
#
#     Recipe ID: The unique number that appends the recipe url on allrecipes.com (integer)
#     Title: The name of the recipe (string)
#     Total time: The number of minutes the recipe should take to prepare and cook. (integer)
#     Ingredients: The ingredients that go into the recipe. (list of strings)
#     Instructions: Step-by-step cooking instructions (list)
#     Rating: The average rating left by users
#     Number of ratings: The number of ratings left by users.

# %%
# # To avoid damaging important information, a separate working copy is made.
# # Searches will best be performed without having to worry about capitalization
# # Results have recipe numbers which can be used to find the entries in the original dataframe so the output has capitalization.
ingr_search_df = recipe_df_cooked.copy()
ingr_search_df['Ingredients'] = recipe_df_cooked['Ingredients'][:].str.lower()

# # Testing.
# ingr_search_df.head(3)

# %%
# # This bit of code is part of an exploration in how to enter a set of text into python and get out that same set of text without quotation marks.
# # It was intended for use with the filtration function as a means by which to remove the need for any quotation marks. 
# lip = 43
# dir(lip)
# attrs = dir(lip)
# attrs

# %%
def rec_by_ingr(ingr):
    result = ingr_search_df[ingr_search_df['Ingredients'].str.contains(ingr.lower())]
    display(result)
# The code below words to call the function
# rec_by_ingr('flour')

# %%
def rec_by_ingr(ingr, ingr2):
    result = ingr_search_df[ingr_search_df['Ingredients'].str.contains(ingr.lower())]
    result2 = result[result['Ingredients'].str.contains(ingr2.lower())]
    display(result2.head(10))
# The code below words to call the function
# rec_by_ingr('onion', 'bacon')

# %%
# ingr_search_df[ingr_search_df['Ingredients'].str.contains('chicken'.lower())][ingr_search_df['Ingredients'].str.contains('water'.lower())]

# %%
txt = "welcome, to the jungle"

x = txt.split(', ')

print(x)
# Out:
# ['welcome', 'to the jungle']

# %%
def search_df():
    ingr_search_df = recipe_df_cooked.copy() # creates a working copy of the dataframe within the function
    ingr_search_df['Ingredients'] = recipe_df_cooked['Ingredients'][:].str.lower() # lowercases the column being searched
    ingredients = input('What ingredients do you want to use? Please separate with commas and spaces ", ":') # search terms entered
    ingredients = ingredients.lower() # lowercases search input
    ingredients_list = ingredients.split(', ') # turns input into list
    length_variable = len(ingredients_list) # counts the length of the input list
    count = 0 # is a count used inside the function to ensure all of the search terms are used.
    
    for i in ingredients_list:
        
        if ingr_search_df[ingr_search_df['Ingredients'].str.contains(i)].shape[0] > 0: # if the search finds a result, proceed.
            ingr_search_df = ingr_search_df[ingr_search_df['Ingredients'].str.contains(i)] # in-function, redefine the df with the search filter
            count += 1 #increase the above count. If it matches the num of search terms function will end 
            continue
            
        elif:
            count += 1
            if count == length_variable:
                if ingr_search_df['Ingredients'].equals(recipe_df_cooked['Ingredients'][:].str.lower()) == True:
                    print("No results. Please try another ingredient.")
                else:
                    continue
            else:
                continue
        else:
            if count !< length_variable: # if count is not less than the number of search terms....
                
                # This needs to be changed. Currently, the function searches for one ingredient, 
                # asks repeatedly if more are desired, then spits out the answer. Other ingredients get ignored.
                # this can be prevented by moving the "Would you like to see more" outside the for loop
                # and instead make it as a function termination sequence. 
                # Currently, the function termination is too nested for this to be viable. 
                # Functionality will need to be altered, the termination (display) methods to be moved to a higher level. 
                
                more = 'y'
                while more.lower() == 'y':
                    display(ingr_search_df.sample(n=5))
                    more = input('Would you like to see five different recipes? Y/N: ')
                if more.lower() == 'y':
                    display(ingr_search_df.sample(n=5))
                    continue
                elif more.lower() == 'n':
                    return
                else:
                    display("Please only type 'Y' or 'N' at prompt.")
search_df()
# Out:
#   File "<ipython-input-615-fdbd250c1bc3>", line 17
#     elif:
#         ^
# SyntaxError: invalid syntax

# %%
# ## V 1.0

# def search_df():
#     ingr_search_df = recipe_df_cooked.copy()
#     ingr_search_df['Ingredients'] = recipe_df_cooked['Ingredients'][:].str.lower()
#     ingredients = input('What ingredients do you want to use? Please separate with commas and spaces ", ":')
#     ingredients = ingredients.lower()
#     ingredients_list = ingredients.split(', ')
#     length_variable = len(ingredients_list)
#     count = 0
#     for i in ingredients_list:
#         if ingr_search_df[ingr_search_df['Ingredients'].str.contains(i)].shape[0] > 0: 
#             ingr_search_df = ingr_search_df[ingr_search_df['Ingredients'].str.contains(i)] # Even with proper syntax... will this work? It doesn't seem like a filter.
#             count += 1
#             if count == length_variable:
#                 display(ingr_search_df)
#             else:
#                 continue
#         else:
#             count += 1
#             if count == length_variable:
#                 if ingr_search_df['Ingredients'].equals(recipe_df_cooked['Ingredients'][:].str.lower()) == True:
#                     print("No results. Please try another ingredient.")
#                 else:
#                     display(ingr_search_df)
#             else:
#                 continue
# search_df()

# %%
# V 2.0

def search_df():
    ingr_search_df = recipe_df_cooked.copy() # creates a working copy of the dataframe within the function
    ingr_search_df['Ingredients'] = recipe_df_cooked['Ingredients'][:].str.lower() # lowercases the column being searched
    ingredients = input('What ingredients do you want to use? Please separate with commas and spaces ", ":') # search terms entered
    ingredients = ingredients.lower() # lowercases search input
    ingredients_list = ingredients.split(', ') # turns input into list
    length_variable = len(ingredients_list) # counts the length of the input list
    count = 0 # is a count used inside the function to ensure all of the search terms are used.
    
    for i in ingredients_list:
        if ingr_search_df[ingr_search_df['Ingredients'].str.contains(i)].shape[0] > 0: # if the search finds a result, proceed.
            ingr_search_df = ingr_search_df[ingr_search_df['Ingredients'].str.contains(i)] # in-function, redefine the df with the search filter
            count += 1 #increase the above count. If it matches the num of search terms function will end 
            if count < length_variable: # if count is less than the number of search terms....
                
                # This needs to be changed. Currently, the function searches for one ingredient, 
                # asks repeatedly if more are desired, then spits out the answer. Other ingredients get ignored.
                # this can be prevented by moving the "Would you like to see more" outside the for loop
                # and instead make it as a function termination sequence. 
                # Currently, the function termination is too nested for this to be viable. 
                # Functionality will need to be altered, the termination (display) methods to be moved to a higher level. 
                
                more = 'y'
                while more.lower() == 'y':
                    display(ingr_search_df.sample(n=5))
                    more = input('Would you like to see five different recipes? Y/N: ')
                if more.lower() == 'y':
                    display(ingr_search_df.sample(n=5))
                    continue
                elif more.lower() == 'n':
                    return
                else:
                    display("Please only type 'Y' or 'N' at prompt.")
            else:
                continue
        else:
            count += 1
            if count == length_variable:
                if ingr_search_df['Ingredients'].equals(recipe_df_cooked['Ingredients'][:].str.lower()) == True:
                    print("No results. Please try another ingredient.")
                else:
                    display(ingr_search_df)
            else:
                continue
search_df()
# Out:
# What ingredients do you want to use? Please separate with commas and spaces ", ":

# %%
# Testing and devoping a version of the code in which arguments are passed.
def rec_by_ingr(*ingredients):
    for ingr in ingredients:
        result = ingr_search_df[ingr_search_df['Ingredients'].str.contains(ingr.lower())]
    display(result)
    
# rec_by_ingr('flour', 'water') # currently, this passes one, then the next, etc. Output is just the last argument.

# %%
ingr_search_df[ingr_search_df['Ingredients'].str.contains('flour'.lower())].count()
ingr_search_df[ingr_search_df['Ingredients'].str.contains('flour'.lower())]
# Out:
#        Unnamed: 0  Recipe Number  \
# 6661         6664           6664
# 6662         6665           6665
# 6663         6666           6666
# 6664         6667           6667
# 6665         6668           6668
# 6666         6669           6669
# 6667         6670           6670
# 6668         6671           6671
# 6669         6672           6672
# 6670         6673           6673
# 6671         6674           6674
# 6673         6676           6676
# 6675         6678           6678
# 6676         6679           6679
# 6677         6680           6680
# 6678         6681           6681
# 6679         6682           6682
# 6680         6683           6683
# 6681         6684           6684
# 6682         6685           6685
# 6683         6686           6686
# 6684         6687           6687
# 6685         6688           6688
# 6686         6689           6689
# 6687         6690           6690
# 6688         6691           6691
# 6689         6692           6692
# 6690         6693           6693
# 6691         6694           6694
# 6692         6695           6695
# ...           ...            ...
# 25149       47355          47355
# 25168       47374          47374
# 25202       47408          47408
# 25220       47426          47426
# 25280       47486          47486
# 25319       47525          47525
# 25321       47527          47527
# 25338       47544          47544
# 25393       47599          47599
# 25438       47644          47644
# 25482       47688          47688
# 25499       47705          47705
# 25568       47774          47774
# 25573       47779          47779
# 25574       47780          47780
# 25671       47877          47877
# 25688       47894          47894
# 25692       47898          47898
# 25697       47903          47903
# 25709       47915          47915
# 25737       47943          47943
# 25774       47980          47980
# 25809       48015          48015
# 25836       48042          48042
# 25837       48043          48043
# 25868       48074          48074
# 25871       48077          48077
# 25882       48088          48088
# 25893       48099          48099
# 25965       48171          48171
#
#                                                    Title  Total Time  \
# 6661   Basil, Roasted Peppers and Monterey Jack Cornb...         100
# 6662                                   Mom's Yeast Rolls           0
# 6663                                Sweet Potato Bread I           0
# 6664                                      Cornish Splits           0
# 6665                                         Orange Buns         170
# 6666                               Jalapeno Cheese Bread           0
# 6667                                  Dee's Health Bread           0
# 6668                                     Oatmeal Bread I           0
# 6669                                  Strawberry Bread I           0
# 6670            Sun Dried Tomato and Asiago Cheese Bread           0
# 6671                                Hawaiian Sweet Bread           0
# 6673                         No Knead Refrigerator Rolls           0
# 6675                                   Sourdough Bread I           0
# 6676                                         Dilly Bread         145
# 6677                                     Pumpkin Bread I          75
# 6678                                        Sy's Challah           0
# 6679                                       Onion Bread I           0
# 6680                      Grandma VanDoren's White Bread           0
# 6681                                     Italian Bread I           0
# 6682                                 Sunday Dinner Rolls           0
# 6683                                  Banana Wheat Bread           0
# 6684                                        Banana Bread          75
# 6685                                 Candied Fruit Bread           0
# 6686                                 Nut and Fruit Bread           0
# 6687                               Mother's Banana Bread          75
# 6688                                Pumpernickel Bread I           0
# 6689                           Sun Dried Tomato Focaccia           0
# 6690                                  Buttermilk Bread I           0
# 6691                             Michell Jenny's Challah         185
# 6692                                      Potato Bread I           0
# ...                                                  ...         ...
# 25149                                    Mustard Pickles          45
# 25168                            Easy Chicken Enchiladas          50
# 25202                          Tammy's  Favorite Lasagna         180
# 25220                              Wonderful Yogurt Cake          65
# 25280                                 Five Spice Muffins          45
# 25319                            Ham and Cheesy Potatoes          85
# 25321                       Very Special Spaghetti Sauce         210
# 25338                         Flea Terminator Dog Treats         210
# 25393                                   Wiener Schnitzel          35
# 25438                                 Mamool or Ma'amoul          87
# 25482                         Chicken Marsala Florentine          35
# 25499                       Polish Chicken and Dumplings         210
# 25568        Honey Ginger Orange Oatmeal Delight Cookies          27
# 25573                        Cocoa-Coconut Oatmeal Nests          30
# 25574                             Easter Basket Cupcakes         110
# 25671                               Tennessee Stack Cake           0
# 25688                             Special Lobster Bisque          35
# 25692                      Black-Eyed Peas and Tortillas          25
# 25697                                  Sweet Irish Bread          75
# 25709                                    Creamy Pear Pie          75
# 25737                             Elegant Wild Rice Soup          90
# 25774                                  Flaky Chicken Pie          85
# 25809                                Cobb Salad Roll-Ups           0
# 25836                         Low Fat Apple Bran Muffins          30
# 25837                               Brown Sugar Biscuits          35
# 25868                         Gel's Green Beans and Beef          35
# 25871                          Warm Chicken Caesar Wraps          28
# 25882                 Oven Fried Chicken & Potato Wedges          50
# 25893                         Tooth-Splitting Gingernuts          29
# 25965                               Burgundy Chicken Pie          85
#
#                                              Ingredients  \
# 6661   ['1/2 cup unsalted butter, chilled and cubed',...
# 6662   ['2 cups hot water', '1/2 cup margarine', '1/3...
# 6663   ['1 1/2 cups white sugar', '1/2 cup vegetable ...
# 6664   ['1 teaspoon active dry yeast', '1 1/4 cups lu...
# 6665   ['1/4 cup butter', '1 teaspoon white sugar', '...
# 6666   ['8 cups all-purpose flour', '4 cups shredded ...
# 6667   ['2 tablespoons active dry yeast', '1 teaspoon...
# 6668   ['1 cup rolled oats', '1/2 cup molasses', '1/3...
# 6669   ['3 cups all-purpose flour', '2 cups white sug...
# 6670   ['1 cup water', '2 tablespoons extra virgin ol...
# 6671   ['1 cup warm water', '5 tablespoons white suga...
# 6673   ['4 1/2 teaspoons active dry yeast', '2 cups w...
# 6675   ['1 cup sourdough starter', '1 1/2 cups warm w...
# 6676   ['1 (.25 ounce) package active dry yeast', '1/...
# 6677   ['3 1/2 cups all-purpose flour', '2 teaspoons ...
# 6678   ['1/4 cup white sugar', '1 tablespoon salt', '...
# 6679   ['2 (.25 ounce) packages active dry yeast', '3...
# 6680   ['3 cups warm water', '3 tablespoons active dr...
# 6681   ['1/4 cup chopped sun-dried tomatoes', '2 1/2 ...
# 6682   ['1 (.25 ounce) package active dry yeast', '1/...
# 6683   ['2 cups whole wheat flour', '1/4 cup wheat ge...
# 6684   ['1 1/2 cups all-purpose flour', '1 teaspoon b...
# 6685   ['2 cups sifted all-purpose flour', '4 teaspoo...
# 6686   ['2 cups sifted all-purpose flour', '4 teaspoo...
# 6687   ['1 3/4 cups all-purpose flour', '2 teaspoons ...
# 6688   ['1 1/2 cups warm milk', '1 1/2 tablespoons ve...
# 6689   ['1 cup water', '3 cups bread flour', '2 table...
# 6690   ['1 1/2 cups buttermilk', '1 1/2 tablespoons m...
# 6691   ['7/8 cup water', '1/2 tablespoon salt', '1/4 ...
# 6692   ['3/4 cup water', '2/3 cup instant mashed pota...
# ...                                                  ...
# 25149  ['8 large cucumbers, sliced', '4 cups sliced o...
# 25168  ['1 (8 ounce) package cream cheese', '1 cup sa...
# 25202  ['4 tablespoons vegetable oil', '1 large onion...
# 25220  ['1/2 cup butter, softened', '1 cup brown suga...
# 25280  ['2 cups shredded zucchini', '1/3 cup boiling ...
# 25319  ['4 tablespoons all-purpose flour', '2 tablesp...
# 25321  ['3/4 cup olive oil', '8 cloves garlic, minced...
# 25338  ['3 cubes beef bouillon', '1 1/2 cups boiling ...
# 25393  ['2 pounds veal', '1 cup all-purpose flour', '...
# 25438  ['2 cups semolina flour', '1 1/2 cups shorteni...
# 25482  ['4 boneless, skinless chicken breast halves',...
# 25499  ['1 (3 pound) whole chicken', '1 onion, choppe...
# 25568  ['2/3 cup triticale flour', '1/2 cup rolled oa...
# 25573  ['3/4 cup butter, softened', '3/4 cup granulat...
# 25574  ['2 cups sugar', '1 3/4 cups all-purpose flour...
# 25671  ['4 cups dried apples', '2 2/3 cups water', '1...
# 25688  ['6 tablespoons butter', '6 tablespoons all-pu...
# 25692  ['1 tablespoon olive oil', '1/4 cup finely cho...
# 25697  ['1/4 cup butter', '1 cup white sugar', '2 egg...
# 25709  ['1/3 cup white sugar', '2 tablespoons all-pur...
# 25737  ['1 cup wild rice', '3 cups water', '6 tablesp...
# 25774  ['6 tyson® fresh boneless, skinless chicken th...
# 25809  ['1 (10 ounce) package tyson® frozen, fully co...
# 25836  ['1 1/2 cups wheat bran', '1 cup low-fat butte...
# 25837  ['2 cups all-purpose flour', '1/4 cup brown su...
# 25868  ['1/2 pound extra-lean ground beef', '1 1/2 ta...
# 25871  ['8 tyson® individually fresh frozen boneless,...
# 25882  ['4 tyson® fresh boneless, skinless chicken th...
# 25893  ['1/2 cup butter, melted', '1 cup white sugar'...
# 25965  ['2 onions, chopped', '2 teaspoons vegetable o...
#
#                                             Instructions  Rating  \
# 6661   Preheat oven to 400 degrees F (205 degrees C)....     NaN
# 6662   Melt margarine in hot water. Add sugar and sal...     NaN
# 6663   Combine sugar and oil; beat well. Add eggs and...     NaN
# 6664   In a small bowl, dissolve the yeast in the mil...     NaN
# 6665   Stir butter and 1 teaspoon sugar into the hot ...     NaN
# 6666   In a very large bowl, combine 7 cups of flour,...     NaN
# 6667   In a small bowl, dissolve the yeast and sugar ...     NaN
# 6668   Combine oats, molasses, oil, salt and boiling ...     NaN
# 6669   Grease and flour a 9 x 5 inch pan well. Prehea...     NaN
# 6670   Place all ingredients into bread machine in or...     NaN
# 6671   Measure ingredients into the bread machine in ...     NaN
# 6673   In a large bowl, dissolve yeast in warm water ...     NaN
# 6675   Mix sugar, corn oil, salt, water, and 1 cup of...     NaN
# 6676   Stir the yeast into the warm water, and add a ...     NaN
# 6677   Preheat oven to 350 degrees F (175 degrees C)....     NaN
# 6678   Place sugar, salt, and oil in either a mixing ...     NaN
# 6679   Warm the milk in a small saucepan until it bub...     NaN
# 6680   In a large bowl, combine warm water, yeast, sa...     NaN
# 6681   Preheat oven to 350 degrees F (175 degrees C)....     NaN
# 6682   In a large bowl, stir yeast, 1/4 cup warm wate...     NaN
# 6683   Grease a 9 x 5 inch loaf pan. Preheat oven to ...     NaN
# 6684   Grease and flour two 7x3 inch loaf pans. Prehe...     NaN
# 6685   Grease an 8 x 5 inch loaf tin thoroughly. Preh...     NaN
# 6686   Grease an 8 x 5 inch loaf tin thoroughly. Preh...     NaN
# 6687   Grease an 8x4 inch loaf pan. Preheat oven to 3...     NaN
# 6688   Place ingredients into the bread machine in or...     NaN
# 6689   Place water, flour, powdered milk, sugar, salt...     NaN
# 6690   Place buttermilk, butter or margarine, sugar, ...     NaN
# 6691   Place water, salt, honey, eggs, melted butter ...     NaN
# 6692   Add ingredients to bread machine in order sugg...     NaN
# ...                                                  ...     ...
# 25149  Place the sliced cucumbers and onions into a l...     NaN
# 25168  Preheat the oven to 350 degrees F (175 degrees...     NaN
# 25202  Heat oil in a large skillet over medium heat. ...     NaN
# 25220  Preheat the oven to 350 degrees F (175 degrees...     NaN
# 25280  Preheat oven to 350 degrees F (175 degrees C)....     NaN
# 25319  Preheat oven to 350 degrees F (175 degrees C)....     NaN
# 25321  Heat olive oil in a large pot over medium heat...     NaN
# 25338  Preheat the oven to 375 degrees F (190 degrees...     NaN
# 25393  Cut the veal into steaks, about as thick as yo...     NaN
# 25438  Place the semolina flour into a medium bowl, a...     NaN
# 25482  Place chicken breasts between two pieces of wa...     NaN
# 25499  Place chicken, onion, and celery in a large po...     NaN
# 25568  Preheat the oven to 350 degrees F (175 degrees...     NaN
# 25573  Heat oven to 350 degrees F.\r\nBeat butter, gr...     NaN
# 25574  Heat oven to 350 degrees F. Line muffin cups (...     NaN
# 25671  In a large saucepan, combine 4 cups of dried a...     NaN
# 25688  Melt the butter in a large pot over medium hea...     NaN
# 25692  Heat the olive oil in a medium skillet over me...     NaN
# 25697  Preheat the oven to 350 degrees F (175 degrees...     NaN
# 25709  Preheat the oven to 400 degrees F (200 degrees...     NaN
# 25737  In a pot, bring the wild rice and water to a b...     NaN
# 25774  Preheat oven to 375 degrees F. CLEAN: Wash han...     NaN
# 25809  PREP: Prepare chicken according to package dir...     NaN
# 25836  In a small bowl, combine bran and buttermilk. ...     NaN
# 25837  Preheat oven to 375 degrees F (190 degrees C)....     NaN
# 25868  In a large skillet over medium heat, mix the g...     NaN
# 25871  Wash hands. Rinse chicken to remove ice glaze....     NaN
# 25882  PREP: Preheat oven to 400 degrees F. CLEAN: Wa...     NaN
# 25893  Preheat the oven to 350 degrees F (175 degrees...     NaN
# 25965  In a large skillet, saute onions in oil over m...     NaN
#
#        Number of Ratings
# 6661                 NaN
# 6662                 NaN
# 6663                 NaN
# 6664                 NaN
# 6665                 NaN
# 6666                 NaN
# 6667                 NaN
# 6668                 NaN
# 6669                 NaN
# 6670                 NaN
# 6671                 NaN
# 6673                 NaN
# 6675                 NaN
# 6676                 NaN
# 6677                 NaN
# 6678                 NaN
# 6679                 NaN
# 6680                 NaN
# 6681                 NaN
# 6682                 NaN
# 6683                 NaN
# 6684                 NaN
# 6685                 NaN
# 6686                 NaN
# 6687                 NaN
# 6688                 NaN
# 6689                 NaN
# 6690                 NaN
# 6691                 NaN
# 6692                 NaN
# ...                  ...
# 25149                NaN
# 25168                NaN
# 25202                NaN
# 25220                NaN
# 25280                NaN
# 25319                NaN
# 25321                NaN
# 25338                NaN
# 25393                NaN
# 25438                NaN
# 25482                NaN
# 25499                NaN
# 25568                NaN
# 25573                NaN
# 25574                NaN
# 25671                NaN
# 25688                NaN
# 25692                NaN
# 25697                NaN
# 25709                NaN
# 25737                NaN
# 25774                NaN
# 25809                NaN
# 25836                NaN
# 25837                NaN
# 25868                NaN
# 25871                NaN
# 25882                NaN
# 25893                NaN
# 25965                NaN
#
# [6047 rows x 8 columns]

# %% [markdown]
# ### Creating a Cookbook, the dictionary to house recipes
# The recipes need to be stored.
# The keys of this dictionary will be the `Recipe ID`, which will also be present in the dictionary. A necessary redundancy.

# %%
![picture](picture URL)
# Out:
# /bin/sh: -c: line 0: syntax error near unexpected token `picture'
# /bin/sh: -c: line 0: `[picture](picture URL)'

# %% [markdown]
# # Recommender System

# %%
import matplotlib as plt
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import matplotlib.pyplot as plt, seaborn as sns
import pandas as pd, numpy as np
from IPython.display import display
# %matplotlib inline

# %%
rr_df
# Out:
#        Unnamed: 0  Recipe Number  \
# 0               3              3
# 1            6663           6663
# 2            6664           6664
# 3            6665           6665
# 4            6666           6666
# 5            6667           6667
# 7            6669           6669
# 8            6670           6670
# 9            6671           6671
# 10           6672           6672
# 11           6673           6673
# 12           6674           6674
# 13           6675           6675
# 14           6676           6676
# 15           6677           6677
# 16           6678           6678
# 17           6679           6679
# 18           6680           6680
# 19           6681           6681
# 20           6682           6682
# 21           6683           6683
# 22           6684           6684
# 23           6685           6685
# 24           6686           6686
# 25           6687           6687
# 28           6690           6690
# 29           6691           6691
# 30           6692           6692
# 31           6693           6693
# 32           6694           6694
# ...           ...            ...
# 15152       47954          47954
# 15153       47965          47965
# 15154       47966          47966
# 15161       47984          47984
# 15167       47995          47995
# 15168       47996          47996
# 15169       47998          47998
# 15171       48002          48002
# 15172       48004          48004
# 15174       48007          48007
# 15179       48020          48020
# 15181       48024          48024
# 15187       48032          48032
# 15188       48035          48035
# 15189       48036          48036
# 15190       48042          48042
# 15191       48043          48043
# 15192       48066          48066
# 15193       48074          48074
# 15195       48076          48076
# 15196       48077          48077
# 15212       48121          48121
# 15213       48123          48123
# 15214       48125          48125
# 15216       48144          48144
# 15217       48150          48150
# 15218       48156          48156
# 15219       48161          48161
# 15220       48171          48171
# 15221       48187          48187
#
#                                                    Title  Total Time  \
# 0               Mexican Strawberry Water (Agua de Fresa)         265
# 1                                   Crispy Cheese Twists           0
# 2      Basil, Roasted Peppers and Monterey Jack Cornb...         100
# 3                                      Mom's Yeast Rolls           0
# 4                                   Sweet Potato Bread I           0
# 5                                         Cornish Splits           0
# 7                                  Jalapeno Cheese Bread           0
# 8                                     Dee's Health Bread           0
# 9                                        Oatmeal Bread I           0
# 10                                    Strawberry Bread I           0
# 11              Sun Dried Tomato and Asiago Cheese Bread           0
# 12                                  Hawaiian Sweet Bread           0
# 13                   The Best Corn Bread You'll Ever Eat          35
# 14                           No Knead Refrigerator Rolls           0
# 15                                   Sourdough Starter I           0
# 16                                     Sourdough Bread I           0
# 17                                           Dilly Bread         145
# 18                                       Pumpkin Bread I          75
# 19                                          Sy's Challah           0
# 20                                         Onion Bread I           0
# 21                        Grandma VanDoren's White Bread           0
# 22                                       Italian Bread I           0
# 23                                   Sunday Dinner Rolls           0
# 24                                    Banana Wheat Bread           0
# 25                                          Banana Bread          75
# 28                                 Mother's Banana Bread          75
# 29                                  Pumpernickel Bread I           0
# 30                             Sun Dried Tomato Focaccia           0
# 31                                    Buttermilk Bread I           0
# 32                               Michell Jenny's Challah         185
# ...                                                  ...         ...
# 15152                  Cheesy Sausage Zucchini Casserole          90
# 15153                                        Orange Rice          10
# 15154                                   Apple Spice Rice          30
# 15161                                Garlic Lime Chicken          25
# 15167                                        Asian Grill          35
# 15168           Black Forest Chicken and Cabbage Skillet          35
# 15169    Chicken and Artichoke Pizza with Fresh Tomatoes          32
# 15171                           Chicken Pasta Parmigiana          30
# 15172                               Chicken Pita Pockets           0
# 15174                                 Chicken Wellington          50
# 15179                           Creamy Chicken Turnovers          40
# 15181                             Crispy Chicken Dippers          40
# 15187                                        Mango Salsa          45
# 15188                  Grilled Beets in Rosemary Vinegar          60
# 15189                                 Cinnamon Ice Cream         110
# 15190                         Low Fat Apple Bran Muffins          30
# 15191                               Brown Sugar Biscuits          35
# 15192                                   Pumpkin Figs Pie          30
# 15193                         Gel's Green Beans and Beef          35
# 15195                Warm Spinach and Rice Chicken Salad          30
# 15196                          Warm Chicken Caesar Wraps          28
# 15212                             Spicy African Yam Soup          40
# 15213                        Vegetable and Tofu Stir-fry          45
# 15214                       Absolutely Ultimate Marinade          15
# 15216                               Zippy Shepherd's Pie          45
# 15217                    A Different Carrot Raisin Salad          15
# 15218                           Ali's Amazing Bruschetta          15
# 15219                                      Texas Tea III           1
# 15220                               Burgundy Chicken Pie          85
# 15221                         Em and Nic's Apple Chicken          30
#
#                                              Ingredients  \
# 0      ['4 cups strawberries, sliced', '1 cup white s...
# 1      ['1/2 cup Parmesan cheese', '3/4 teaspoon grou...
# 2      ['1/2 cup unsalted butter, chilled and cubed',...
# 3      ['2 cups hot water', '1/2 cup margarine', '1/3...
# 4      ['1 1/2 cups white sugar', '1/2 cup vegetable ...
# 5      ['1 teaspoon active dry yeast', '1 1/4 cups lu...
# 7      ['8 cups all-purpose flour', '4 cups shredded ...
# 8      ['2 tablespoons active dry yeast', '1 teaspoon...
# 9      ['1 cup rolled oats', '1/2 cup molasses', '1/3...
# 10     ['3 cups all-purpose flour', '2 cups white sug...
# 11     ['1 cup water', '2 tablespoons extra virgin ol...
# 12     ['1 cup warm water', '5 tablespoons white suga...
# 13     ['1 egg', '1 1/3 cups milk', '1/4 cup vegetabl...
# 14     ['4 1/2 teaspoons active dry yeast', '2 cups w...
# 15     ['3 tablespoons instant mashed potato flakes',...
# 16     ['1 cup sourdough starter', '1 1/2 cups warm w...
# 17     ['1 (.25 ounce) package active dry yeast', '1/...
# 18     ['3 1/2 cups all-purpose flour', '2 teaspoons ...
# 19     ['1/4 cup white sugar', '1 tablespoon salt', '...
# 20     ['2 (.25 ounce) packages active dry yeast', '3...
# 21     ['3 cups warm water', '3 tablespoons active dr...
# 22     ['1/4 cup chopped sun-dried tomatoes', '2 1/2 ...
# 23     ['1 (.25 ounce) package active dry yeast', '1/...
# 24     ['2 cups whole wheat flour', '1/4 cup wheat ge...
# 25     ['1 1/2 cups all-purpose flour', '1 teaspoon b...
# 28     ['1 3/4 cups all-purpose flour', '2 teaspoons ...
# 29     ['1 1/2 cups warm milk', '1 1/2 tablespoons ve...
# 30     ['1 cup water', '3 cups bread flour', '2 table...
# 31     ['1 1/2 cups buttermilk', '1 1/2 tablespoons m...
# 32     ['7/8 cup water', '1/2 tablespoon salt', '1/4 ...
# ...                                                  ...
# 15152  ['1/2 cup uncooked white rice', '1 cup water',...
# 15153  ['1 teaspoon grated orange zest', '1 1/2 cups ...
# 15154  ['3 tablespoons butter', '1 cup long grain ric...
# 15161  ['4 Tyson® Fresh Boneless, Skinless Chicken Br...
# 15167  ['4 Tyson® Individually Fresh Frozen® Boneless...
# 15168  ['1 (22.4 ounce) package Tyson® Fresh Boneless...
# 15169  ['3 Tyson® Fresh Boneless, Skinless Chicken Br...
# 15171  ['1 (10.5 ounce) package Tyson® Frozen, Fully ...
# 15172  ['1 (9 ounce) package Tyson® Frozen, Fully Coo...
# 15174  ['4 Tyson® Individually Fresh Frozen® Boneless...
# 15179  ['3 cups cooked, diced Tyson® Fresh Pick of th...
# 15181  ['16 Tyson® Fresh Chicken Breast Tenders', '1/...
# 15187  ['1 mango - peeled, seeded, and chopped', '1/4...
# 15188  ['1/3 cup balsamic vinegar', '1 teaspoon chopp...
# 15189  ['1 cup white sugar', '1 1/2 cups half-and-hal...
# 15190  ['1 1/2 cups wheat bran', '1 cup low-fat butte...
# 15191  ['2 cups all-purpose flour', '1/4 cup brown su...
# 15192  ['1 (9 inch) unbaked pie crust', '2 pears - pe...
# 15193  ['1/2 pound extra-lean ground beef', '1 1/2 ta...
# 15195  ['2 Tyson® Individually Fresh Frozen Boneless,...
# 15196  ['8 Tyson® Individually Fresh Frozen Boneless,...
# 15212  ['1 teaspoon vegetable oil', '1 small onion, c...
# 15213  ['1 tablespoon vegetable oil', '1/2 medium oni...
# 15214  ['2 tablespoons sesame seeds', '1 bunch green ...
# 15216  ['1 pound potatoes, peeled and chopped', '1 ta...
# 15217  ['3 large carrots, shredded', '1 cup raisins',...
# 15218  ['2 large tomatoes, coarsely chopped', '1/2 sw...
# 15219  ['1/2 fluid ounce vodka', '1/2 fluid ounce amb...
# 15220  ['2 onions, chopped', '2 teaspoons vegetable o...
# 15221  ['2 boneless, skinless chicken breast halves, ...
#
#                                             Instructions    Rating  \
# 0                                                    NaN  4.650000
# 1      Combine parmesan cheese, pepper and garlic pow...  4.176471
# 2      Preheat oven to 400 degrees F (205 degrees C)....  4.327586
# 3      Melt margarine in hot water. Add sugar and sal...  3.623116
# 4      Combine sugar and oil; beat well. Add eggs and...  4.701755
# 5      In a small bowl, dissolve the yeast in the mil...  4.339449
# 7      In a very large bowl, combine 7 cups of flour,...  4.313044
# 8      In a small bowl, dissolve the yeast and sugar ...  4.806061
# 9      Combine oats, molasses, oil, salt and boiling ...  4.594594
# 10     Grease and flour a 9 x 5 inch pan well. Prehea...  3.954545
# 11     Place all ingredients into bread machine in or...  4.508197
# 12     Measure ingredients into the bread machine in ...  4.250000
# 13     Heat oven to 425 degrees F (220 degrees C). Gr...  3.602410
# 14     In a large bowl, dissolve yeast in warm water ...  4.384615
# 15     Combine instant potatoes, sugar, water, and ye...  4.601852
# 16     Mix sugar, corn oil, salt, water, and 1 cup of...  4.478814
# 17     Stir the yeast into the warm water, and add a ...  4.586207
# 18     Preheat oven to 350 degrees F (175 degrees C)....  4.577381
# 19     Place sugar, salt, and oil in either a mixing ...  4.623656
# 20     Warm the milk in a small saucepan until it bub...  4.500000
# 21     In a large bowl, combine warm water, yeast, sa...  4.776410
# 22     Preheat oven to 350 degrees F (175 degrees C)....  3.965517
# 23     In a large bowl, stir yeast, 1/4 cup warm wate...  4.462766
# 24     Grease a 9 x 5 inch loaf pan. Preheat oven to ...  4.570707
# 25     Grease and flour two 7x3 inch loaf pans. Prehe...  4.687770
# 28     Grease an 8x4 inch loaf pan. Preheat oven to 3...  4.449827
# 29     Place ingredients into the bread machine in or...  3.833333
# 30     Place water, flour, powdered milk, sugar, salt...  4.381579
# 31     Place buttermilk, butter or margarine, sugar, ...  3.794872
# 32     Place water, salt, honey, eggs, melted butter ...  4.739583
# ...                                                  ...       ...
# 15152  Combine the rice and water in a small saucepan...  4.530406
# 15153  In a saucepan over medium-high heat, combine t...  4.000000
# 15154  Melt butter in a saucepan over medium heat. St...  4.139535
# 15161  Wash hands. Place chicken in resealable plasti...  4.136364
# 15167  To prepare marinade, combine orange juice, ter...  4.142857
# 15168  COOK: CLEAN: Wash hands. Sprinkle chicken with...  2.500000
# 15169  Preheat oven to 425 degrees F. Wash hands. Cut...  4.449275
# 15171  COOK: CLEAN: Wash hands. Preheat oven to 425 d...  4.125000
# 15172  Wash hands. Blend salad dressing and dill in a...  4.625000
# 15174  Preheat oven to 375 degrees F. Combine water a...  4.000000
# 15179  PREP: Preheat oven to 425 degrees F. CLEAN: Wa...  4.000000
# 15181  Preheat oven to 375 degrees F. Line jelly roll...  4.166667
# 15187  In a medium bowl, mix mango, red bell pepper, ...  4.672451
# 15188  In a medium bowl, mix balsamic vinegar, rosema...  4.268293
# 15189  In a saucepan over medium-low heat, stir toget...  4.723112
# 15190  In a small bowl, combine bran and buttermilk. ...  4.000000
# 15191  Preheat oven to 375 degrees F (190 degrees C)....  4.215686
# 15192  Preheat the oven to 350 degrees F (175 degrees...  3.666667
# 15193  In a large skillet over medium heat, mix the g...  3.966102
# 15195  PREP: CLEAN: Wash hands. Remove protective ice...  4.444445
# 15196  Wash hands. Rinse chicken to remove ice glaze....  3.714286
# 15212  Heat the oil in a stockpot over medium heat. S...  4.563107
# 15213  In a large skillet, heat oil over medium-high ...  3.843750
# 15214  Place the sesame seeds in a dry skillet over m...  4.637362
# 15216  Bring a large pot of lightly salted water to a...       NaN
# 15217  In a medium bowl, combine shredded carrots, ra...       NaN
# 15218  Preheat oven to 400 degrees F (200 degrees C)....       NaN
# 15219  In a tall glass filled with ice, combine vodka...       NaN
# 15220  In a large skillet, saute onions in oil over m...       NaN
# 15221  Place the chicken in a medium skillet over med...       NaN
#
#        Number of Ratings
# 0                   80.0
# 1                   68.0
# 2                   58.0
# 3                  199.0
# 4                  456.0
# 5                  109.0
# 7                  115.0
# 8                  165.0
# 9                   37.0
# 10                  44.0
# 11                  61.0
# 12                  60.0
# 13                  83.0
# 14                  52.0
# 15                 108.0
# 16                 236.0
# 17                  58.0
# 18                 168.0
# 19                  93.0
# 20                  24.0
# 21                 975.0
# 22                  29.0
# 23                 188.0
# 24                 198.0
# 25                1390.0
# 28                 289.0
# 29                  18.0
# 30                  76.0
# 31                  39.0
# 32                  96.0
# ...                  ...
# 15152              296.0
# 15153               29.0
# 15154               43.0
# 15161               22.0
# 15167               14.0
# 15168                8.0
# 15169               69.0
# 15171                8.0
# 15172                8.0
# 15174                7.0
# 15179                9.0
# 15181                6.0
# 15187              461.0
# 15188               41.0
# 15189              437.0
# 15190               90.0
# 15191               51.0
# 15192                9.0
# 15193              118.0
# 15195                9.0
# 15196               14.0
# 15212              206.0
# 15213              128.0
# 15214               91.0
# 15216                NaN
# 15217                NaN
# 15218                NaN
# 15219                NaN
# 15220                NaN
# 15221                NaN
#
# [10136 rows x 8 columns]

# %%
# Currently, the DataFrame contains a lot of extra information we don't need. 
# Recipe info can be referred to by use of the Recipe Number
# Only 'Recipe Number', 'Rating', and 'Number of Ratings' are needed.

# %%
rr_df_t_raw = rr_df[['Recipe Number', 'Rating']]
rr_df_t_raw['Recipe Number'] = rr_df_t_raw['Recipe Number'].astype(int)
rr_df_t_cooking = rr_df_t_raw.transpose()
rr_df_t_cooked = rr_df_t_cooking.rename(columns=rr_df_t_cooking.iloc[0]) 
rr_df_go = rr_df_t_cooked.drop('Recipe Number')
rr_df_go
# Out:
# /Users/samuel/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#         3.0       6663.0    6664.0    6665.0    6666.0    6667.0    6669.0   \
# Rating     4.65  4.176471  4.327586  3.623116  4.701755  4.339449  4.313044
#
#          6670.0    6671.0    6672.0    ...      48077.0   48121.0  48123.0  \
# Rating  4.806061  4.594594  3.954545   ...     3.714286  4.563107  3.84375
#
#          48125.0  48144.0  48150.0  48156.0  48161.0  48171.0  48187.0
# Rating  4.637362      NaN      NaN      NaN      NaN      NaN      NaN
#
# [1 rows x 10136 columns]

# %% [markdown]
# It would be best if the recommender system had columns representing recipes (done) and rows representing users.
# Currently it only has the output rating for the recipe from the site!
# This will be converted to a single super-user's set of ratings. This person has tried them all!
# The rest will be generated randomly.

# %%
rr_df_go.shape
# Out:
# (1, 10136)

# %%
# The code below says:
# "Here's a list of users. Add them as rows to the df and add random ratings between 0 (inclusive) and 6 (exclusive)"
# In the future, users may best be added with a User ID number, but for now names are used.
rr_df2 = rr_df_go.copy()

users = ['Owen', 'Harrison', 'Isaiah', 'Jordan', 
         'Matthew', 'Eric', 'Jack', 'Rex', 'Martim', 
         'Jason', 'Christopher', 'Katrina', 'Theodore', 
         'Dustin', 'Dan', 'Jeffrey', 'Joshua', 
         'Alex', 'Yuming', 'Bethany', 'Jordan']

for u in users:
    rr_df2.loc[u] = np.random.randint(0, 6, rr_df2.shape[1])

# %%
rr_df3 = rr_df2.rename({'Rating': 'Allrecipes Official'}, axis='index')

# %%
# allrecipes has a 1-5 (inclusive) rating, so we need to turn the zero-value cells to NA. 
# This will be collaborative filtering, in which users will see items liked by users with similar taste.

# %%
rr_df4 = rr_df3.replace({0:np.nan})

# %%
rr_df4.head()
# Out:
#                      3.0       6663.0    6664.0    6665.0    6666.0   \
# Allrecipes Official     4.65  4.176471  4.327586  3.623116  4.701755
# Owen                    5.00       NaN  3.000000  2.000000  1.000000
# Harrison                5.00  3.000000  4.000000  3.000000  2.000000
# Isaiah                  4.00       NaN  1.000000  4.000000  2.000000
# Jordan                  4.00  1.000000  4.000000  1.000000  5.000000
#
#                       6667.0    6669.0    6670.0    6671.0    6672.0   \
# Allrecipes Official  4.339449  4.313044  4.806061  4.594594  3.954545
# Owen                 1.000000  2.000000  3.000000  4.000000  4.000000
# Harrison             3.000000  5.000000  2.000000  4.000000       NaN
# Isaiah               1.000000  2.000000  4.000000  1.000000  2.000000
# Jordan                    NaN  4.000000  1.000000  5.000000  1.000000
#
#                       ...      48077.0   48121.0  48123.0   48125.0  48144.0  \
# Allrecipes Official   ...     3.714286  4.563107  3.84375  4.637362      NaN
# Owen                  ...     5.000000  5.000000  4.00000       NaN      4.0
# Harrison              ...     1.000000  2.000000  5.00000  1.000000      3.0
# Isaiah                ...     1.000000  4.000000  3.00000  4.000000      3.0
# Jordan                ...     4.000000  1.000000  3.00000  3.000000      5.0
#
#                      48150.0  48156.0  48161.0  48171.0  48187.0
# Allrecipes Official      NaN      NaN      NaN      NaN      NaN
# Owen                     5.0      2.0      4.0      1.0      1.0
# Harrison                 5.0      3.0      4.0      1.0      NaN
# Isaiah                   3.0      5.0      1.0      5.0      3.0
# Jordan                   1.0      4.0      1.0      4.0      3.0
#
# [5 rows x 10136 columns]

# %%
def mean_center_rows(df):
    return (df.T - df.mean(axis=1)).T

rr_df_mc = mean_center_rows(rr_df4)
rr_df_mc.head()
# Out:
#                       3.0       6663.0    6664.0    6665.0    6666.0   \
# Allrecipes Official  0.393572 -0.079957  0.071158 -0.633313  0.445326
# Owen                 2.008157       NaN  0.008157 -0.991843 -1.991843
# Harrison             1.996810 -0.003190  0.996810 -0.003190 -1.003190
# Isaiah               1.001306       NaN -1.998694  1.001306 -0.998694
# Jordan               1.033672 -1.966328  1.033672 -1.966328  2.033672
#
#                       6667.0    6669.0    6670.0    6671.0    6672.0   \
# Allrecipes Official  0.083021  0.056615  0.549633  0.338166 -0.301883
# Owen                -1.991843 -0.991843  0.008157  1.008157  1.008157
# Harrison            -0.003190  1.996810 -1.003190  0.996810       NaN
# Isaiah              -1.998694 -0.998694  1.001306 -1.998694 -0.998694
# Jordan                    NaN  1.033672 -1.966328  2.033672 -1.966328
#
#                        ...      48077.0   48121.0   48123.0   48125.0  \
# Allrecipes Official    ...    -0.542143  0.306679 -0.412678  0.380934
# Owen                   ...     2.008157  2.008157  1.008157       NaN
# Harrison               ...    -2.003190 -1.003190  1.996810 -2.003190
# Isaiah                 ...    -1.998694  1.001306  0.001306  1.001306
# Jordan                 ...     1.033672 -1.966328  0.033672  0.033672
#
#                       48144.0   48150.0   48156.0   48161.0   48171.0  \
# Allrecipes Official       NaN       NaN       NaN       NaN       NaN
# Owen                 1.008157  2.008157 -0.991843  1.008157 -1.991843
# Harrison            -0.003190  1.996810 -0.003190  0.996810 -2.003190
# Isaiah               0.001306  0.001306  2.001306 -1.998694  2.001306
# Jordan               2.033672 -1.966328  1.033672 -1.966328  1.033672
#
#                       48187.0
# Allrecipes Official       NaN
# Owen                -1.991843
# Harrison                  NaN
# Isaiah               0.001306
# Jordan               0.033672
#
# [5 rows x 10136 columns]

# %%
rr_df_mc = rr_df_mc.fillna(0)
rr_df_mc.head()
# Out:
#                       3.0       6663.0    6664.0    6665.0    6666.0   \
# Allrecipes Official  0.393572 -0.079957  0.071158 -0.633313  0.445326
# Owen                 2.008157  0.000000  0.008157 -0.991843 -1.991843
# Harrison             1.996810 -0.003190  0.996810 -0.003190 -1.003190
# Isaiah               1.001306  0.000000 -1.998694  1.001306 -0.998694
# Jordan               1.033672 -1.966328  1.033672 -1.966328  2.033672
#
#                       6667.0    6669.0    6670.0    6671.0    6672.0   \
# Allrecipes Official  0.083021  0.056615  0.549633  0.338166 -0.301883
# Owen                -1.991843 -0.991843  0.008157  1.008157  1.008157
# Harrison            -0.003190  1.996810 -1.003190  0.996810  0.000000
# Isaiah              -1.998694 -0.998694  1.001306 -1.998694 -0.998694
# Jordan               0.000000  1.033672 -1.966328  2.033672 -1.966328
#
#                        ...      48077.0   48121.0   48123.0   48125.0  \
# Allrecipes Official    ...    -0.542143  0.306679 -0.412678  0.380934
# Owen                   ...     2.008157  2.008157  1.008157  0.000000
# Harrison               ...    -2.003190 -1.003190  1.996810 -2.003190
# Isaiah                 ...    -1.998694  1.001306  0.001306  1.001306
# Jordan                 ...     1.033672 -1.966328  0.033672  0.033672
#
#                       48144.0   48150.0   48156.0   48161.0   48171.0  \
# Allrecipes Official  0.000000  0.000000  0.000000  0.000000  0.000000
# Owen                 1.008157  2.008157 -0.991843  1.008157 -1.991843
# Harrison            -0.003190  1.996810 -0.003190  0.996810 -2.003190
# Isaiah               0.001306  0.001306  2.001306 -1.998694  2.001306
# Jordan               2.033672 -1.966328  1.033672 -1.966328  1.033672
#
#                       48187.0
# Allrecipes Official  0.000000
# Owen                -1.991843
# Harrison             0.000000
# Isaiah               0.001306
# Jordan               0.033672
#
# [5 rows x 10136 columns]

# %%
allrecipes_official_mc = rr_df_mc.loc['Allrecipes Official',:].values.reshape(1,-1)
owen_mc                = rr_df_mc.loc['Owen',:].values.reshape(1,-1)
harrison_mc            = rr_df_mc.loc['Harrison',:].values.reshape(1,-1)
isaiah_mc              = rr_df_mc.loc['Isaiah',:].values.reshape(1,-1)
jordan_mc              = rr_df_mc.loc['Jordan',:].values.reshape(1,-1)
matthew_mc             = rr_df_mc.loc['Matthew',:].values.reshape(1,-1)
eric_mc                = rr_df_mc.loc['Eric',:].values.reshape(1,-1)
jack_mc                = rr_df_mc.loc['Jack',:].values.reshape(1,-1)
rex_mc                 = rr_df_mc.loc['Rex',:].values.reshape(1,-1)
martim_mc              = rr_df_mc.loc['Martim',:].values.reshape(1,-1)
jason_mc               = rr_df_mc.loc['Jason',:].values.reshape(1,-1)
christopher_mc         = rr_df_mc.loc['Christopher',:].values.reshape(1,-1)
katrina_mc             = rr_df_mc.loc['Katrina',:].values.reshape(1,-1)
theodore_mc            = rr_df_mc.loc['Theodore',:].values.reshape(1,-1)
dustin_mc              = rr_df_mc.loc['Dustin',:].values.reshape(1,-1)
dan_mc                 = rr_df_mc.loc['Dan',:].values.reshape(1,-1)
jeffrey_mc             = rr_df_mc.loc['Jeffrey',:].values.reshape(1,-1)
joshua_mc              = rr_df_mc.loc['Joshua',:].values.reshape(1,-1)
alex_mc                = rr_df_mc.loc['Alex',:].values.reshape(1,-1)
yuming_mc              = rr_df_mc.loc['Yuming',:].values.reshape(1,-1)
bethany_mc             = rr_df_mc.loc['Bethany',:].values.reshape(1,-1)
jordan_mc              = rr_df_mc.loc['Jordan',:].values.reshape(1,-1)

# %%
cosine_similarity(jordan_mc, bethany_mc)
# Out:
# array([[-0.00355865]])

# %%
sim_matrix = cosine_similarity(rr_df_mc)
rr_sim = pd.DataFrame(sim_matrix, columns=rr_df_mc.index, index=rr_df_mc.index)
sns.heatmap(rr_sim, annot=False, cmap='coolwarm')

# %%
rr_df4.head()
# Out:
#                      3.0       6663.0    6664.0    6665.0    6666.0   \
# Allrecipes Official     4.65  4.176471  4.327586  3.623116  4.701755
# Owen                    5.00       NaN  3.000000  2.000000  1.000000
# Harrison                5.00  3.000000  4.000000  3.000000  2.000000
# Isaiah                  4.00       NaN  1.000000  4.000000  2.000000
# Jordan                  4.00  1.000000  4.000000  1.000000  5.000000
#
#                       6667.0    6669.0    6670.0    6671.0    6672.0   \
# Allrecipes Official  4.339449  4.313044  4.806061  4.594594  3.954545
# Owen                 1.000000  2.000000  3.000000  4.000000  4.000000
# Harrison             3.000000  5.000000  2.000000  4.000000       NaN
# Isaiah               1.000000  2.000000  4.000000  1.000000  2.000000
# Jordan                    NaN  4.000000  1.000000  5.000000  1.000000
#
#                       ...      48077.0   48121.0  48123.0   48125.0  48144.0  \
# Allrecipes Official   ...     3.714286  4.563107  3.84375  4.637362      NaN
# Owen                  ...     5.000000  5.000000  4.00000       NaN      4.0
# Harrison              ...     1.000000  2.000000  5.00000  1.000000      3.0
# Isaiah                ...     1.000000  4.000000  3.00000  4.000000      3.0
# Jordan                ...     4.000000  1.000000  3.00000  3.000000      5.0
#
#                      48150.0  48156.0  48161.0  48171.0  48187.0
# Allrecipes Official      NaN      NaN      NaN      NaN      NaN
# Owen                     5.0      2.0      4.0      1.0      1.0
# Harrison                 5.0      3.0      4.0      1.0      NaN
# Isaiah                   3.0      5.0      1.0      5.0      3.0
# Jordan                   1.0      4.0      1.0      4.0      3.0
#
# [5 rows x 10136 columns]

# %%
rr_sim.head()
# Out:
#                      Allrecipes Official      Owen  Harrison    Isaiah  \
# Allrecipes Official             1.000000  0.002131  0.019635 -0.010880
# Owen                            0.002131  1.000000 -0.002258  0.003591
# Harrison                        0.019635 -0.002258  1.000000  0.008578
# Isaiah                         -0.010880  0.003591  0.008578  1.000000
# Jordan                          0.006987  0.003088 -0.000832 -0.007551
#
#                        Jordan   Matthew      Eric      Jack       Rex  \
# Allrecipes Official  0.006987 -0.005415 -0.012928  0.008346  0.002031
# Owen                 0.003088  0.027205  0.002306  0.011634 -0.003400
# Harrison            -0.000832 -0.016944  0.017394 -0.014982 -0.017763
# Isaiah              -0.007551  0.018292  0.003714  0.004690 -0.000624
# Jordan               1.000000  0.013532 -0.013936  0.001400 -0.007246
#
#                        Martim    ...     Christopher   Katrina  Theodore  \
# Allrecipes Official  0.003420    ...        0.020414 -0.011844  0.004176
# Owen                 0.008693    ...        0.011462  0.007901  0.012676
# Harrison            -0.000388    ...        0.018153  0.002141  0.014764
# Isaiah               0.003721    ...        0.001015  0.007776 -0.019033
# Jordan              -0.007157    ...        0.006268  0.005578  0.025291
#
#                        Dustin       Dan   Jeffrey    Joshua      Alex  \
# Allrecipes Official -0.009956  0.010080  0.016324  0.021678  0.003768
# Owen                 0.012332 -0.003982 -0.011044  0.005658 -0.006735
# Harrison             0.003764 -0.009724  0.004508 -0.007068  0.009613
# Isaiah              -0.002711 -0.011025  0.002446  0.009299  0.001215
# Jordan              -0.003190 -0.015595 -0.007660 -0.000569  0.015135
#
#                        Yuming   Bethany
# Allrecipes Official -0.003395 -0.005026
# Owen                -0.007951  0.000999
# Harrison            -0.014087 -0.014015
# Isaiah               0.033059 -0.003580
# Jordan              -0.009488 -0.003559
#
# [5 rows x 21 columns]

# %%
# Lets check Isaiah's similarity to other users!
# get Nancy's similarity scores
isaiah_sim = rr_sim['Isaiah']#.drop('Isaiah')
# isaiah_sim_pos = isaiah_sim[isaiah_sim > 0]
isaiah_sim
# Out:
# Allrecipes Official   -0.010880
# Owen                   0.003591
# Harrison               0.008578
# Isaiah                 1.000000
# Jordan                -0.007551
# Matthew                0.018292
# Eric                   0.003714
# Jack                   0.004690
# Rex                   -0.000624
# Martim                 0.003721
# Jason                 -0.005331
# Christopher            0.001015
# Katrina                0.007776
# Theodore              -0.019033
# Dustin                -0.002711
# Dan                   -0.011025
# Jeffrey                0.002446
# Joshua                 0.009299
# Alex                   0.001215
# Yuming                 0.033059
# Bethany               -0.003580
# Name: Isaiah, dtype: float64

# %%
isaiah_weights = isaiah_sim.values/np.sum(isaiah_sim.values)

# %%
allrecipes_official_sim = rr_sim['Allrecipes Official']
owen_sim = rr_sim['Owen']
harrison_sim = rr_sim['Harrison']
isaiah_sim = rr_sim['Isaiah']
jordan_sim = rr_sim['Jordan']
matthew_sim = rr_sim['Matthew']
eric_sim = rr_sim['Eric']
jack_sim = rr_sim['Jack']
rex_sim = rr_sim['Rex']
martim_sim = rr_sim['Martim']
jason_sim = rr_sim['Jason']
christopher_sim = rr_sim['Christopher']
katrina_sim = rr_sim['Katrina']
theodore_sim = rr_sim['Theodore']
dustin_sim = rr_sim['Dustin']
dan_sim = rr_sim['Dan']
jeffrey_sim = rr_sim['Jeffrey']
joshua_sim = rr_sim['Joshua']
alex_sim = rr_sim['Alex']
yuming_sim = rr_sim['Yuming']
bethany_sim = rr_sim['Bethany']
jordan_sim = rr_sim['Jordan']

# %%
allrecipes_official_weights = allrecipes_official_sim.values/np.sum(allrecipes_official_sim.values)
owen_weights = owen_sim.values/np.sum(owen_sim.values)
harrison_weights = harrison_sim.values/np.sum(harrison_sim.values)
isaiah_weights = isaiah_sim.values/np.sum(isaiah_sim.values)
jordan_weights = jordan_sim.values/np.sum(jordan_sim.values)
matthew_weights = matthew_sim.values/np.sum(matthew_sim.values)
eric_weights = eric_sim.values/np.sum(eric_sim.values)
jack_weights = jack_sim.values/np.sum(jack_sim.values)
rex_weights = rex_sim.values/np.sum(rex_sim.values)
martim_weights = martim_sim.values/np.sum(martim_sim.values)
jason_weights = jason_sim.values/np.sum(jason_sim.values)
christopher_weights = christopher_sim.values/np.sum(christopher_sim.values)
katrina_weights = katrina_sim.values/np.sum(katrina_sim.values)
theodore_weights = theodore_sim.values/np.sum(theodore_sim.values)
dustin_weights = dustin_sim.values/np.sum(dustin_sim.values)
dan_weights = dan_sim.values/np.sum(dan_sim.values)
jeffrey_weights = jeffrey_sim.values/np.sum(jeffrey_sim.values)
joshua_weights = joshua_sim.values/np.sum(joshua_sim.values)
alex_weights = alex_sim.values/np.sum(alex_sim.values)
yuming_weights = yuming_sim.values/np.sum(yuming_sim.values)
bethany_weights = bethany_sim.values/np.sum(bethany_sim.values)
jordan_weights = jordan_sim.values/np.sum(jordan_sim.values)

# %% [markdown]
# Who likes Mulligatawney soup as much as Isaiah!?

# %%
# Get ratings for item 13087
ratings_13087_full = rr_df3[13087].loc[rr_sim.index]
ratings_13087 = ratings_13087_full.drop('Isaiah')

# %%
np.dot(ratings_13087.values, isaiah_weights)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-819-88529787cf4b> in <module>()
# ----> 1 np.dot(ratings_13087.values, isaiah_weights)
#
# ValueError: shapes (20,) and (21,) not aligned: 20 (dim 0) != 21 (dim 0)

# %%
ratings = users.T
ratings = ratings[ratings['Nancy'].isnull()]
ratings = ratings.drop('Nancy', axis=1)
ratings = ratings[nancy_sim.index]

nancy_ratings = np.dot(ratings.fillna(0).values, nancy_weights)
nancy_ratings
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-811-44ef5beba043> in <module>()
# ----> 1 ratings = users.T
#       2 ratings = ratings[ratings['Nancy'].isnull()]
#       3 ratings = ratings.drop('Nancy', axis=1)
#       4 ratings = ratings[nancy_sim.index]
#       5
#
# AttributeError: 'list' object has no attribute 'T'
